# %% [markdown]
# # Make Regression

# %% [markdown]
# Generating synthetic regression dataset

# %%
from sklearn.datasets import make_regression

# Generate synthetic regression dataset
X, y = make_regression(n_samples=100, n_features=1, noise=15, random_state=42)

# %% [markdown]
# Plotting the dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# Generate synthetic regression dataset
X, y = make_regression(n_samples=100, n_features=1, noise=15, random_state=42)

#How to plot it
y = y.reshape(-1, 1)
m = X.shape[0]

X_b = np.c_[np.ones((m, 1)), X]


plt.figure(figsize=(10, 5))
plt.scatter(X, y, color="blue", label="Actual Data")
plt.xlabel("Feature")
plt.ylabel("Target")
plt.title("Linear Regression Without Gradient Descent")
plt.legend()
plt.show()

# %% [markdown]
# Parameters that can vary using make regression:
#
# *   **number of instances:** n_sample
# *   **number of classes:**
# *   **proportion of classes:**
# *   **distribution within class:**
# * **shape of class borders:** *not possible - regression does not involve decision boundaries*
# * **level of noise:** noise
# * **overlap between classes:**
# * *random_state controls reproducibility*

# %% [markdown]
# # Make Blobs

# %%
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors

# X: 240 coordinates (our dataset)
# XXX: cluster of each point
X,XXX = make_blobs(n_samples=[50,20,50,120], centers=[(2,5),(5,6),(8,5),(5,2)],
                 n_features=2, cluster_std=[1,1,1,1],
                 random_state=1, shuffle=False)

# define half of the points of class 0 and half of class 1 (2 classes)
y=np.array([0]*120+[1]*120)

cmap = colors.ListedColormap(['blue','orange'])

# manually define border points for the decision boundary
bdb=[(0,0),(4,4),(6,4),(10,0)]
xbdb=np.array([x for (x,_) in bdb ])
ybdb=np.array([y for (_,y) in bdb ])

ax=plt.axes()
ax.scatter(X[:,0],X[:,1],color=cmap(y))
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')

# to plot the centers
centers=[(2,5),(5,6),(8,5),(5,2)]
for (c1,c2) in centers:
    ax.scatter(c1,c2,color='black')

ax.plot(xbdb,ybdb,color='red')

# %% [markdown]
# # Make moons

# %%
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=300, noise=0.2, random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm')
plt.title("make_moons (nonlinear boundary)")
plt.show()

# %% [markdown]
# # Make Circles

# %%
from sklearn.datasets import make_circles

X, y = make_circles(n_samples=300, noise=0.1, factor=0.5, random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='Set1')
plt.title("make_circles (nonlinear, radial)")
plt.axis("equal")
plt.show()

# %% [markdown]
# # Make classification

# %%
from sklearn.datasets import make_classification

X, y = make_classification(n_samples=300, n_features=2, n_redundant=0,
                           n_informative=2, n_clusters_per_class=1,
                           class_sep=1.5, flip_y=0.1, weights=[0.7, 0.3],
                           random_state=42)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr')
plt.title("make_classification (customizable)")
plt.show()

# %% [markdown]
# # Make multi label classification

# %%
from sklearn.datasets import make_multilabel_classification

X, y = make_multilabel_classification(n_samples=100, n_features=2, n_classes=3, random_state=0)

plt.scatter(X[:, 0], X[:, 1], c=y[:, 0], cmap='Set1')
plt.title("make_multilabel_classification (class 0 shown)")
plt.show()

# %% [markdown]
# # Metrics

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import make_scorer, f1_score

iris = load_iris()
X, y = iris.data, iris.target

model = LogisticRegression(max_iter=200)

# Use macro F1 to treat all classes equally
scores = cross_val_score(model, X, y, cv=5, scoring='f1_macro')

print(f"F1 scores: {scores}")
print(f"Mean F1: {scores.mean():.3f}")

# %% [markdown]
# ![Screenshot 2025-04-05 at 13.45.25.png](data:image/png;base64,...)
